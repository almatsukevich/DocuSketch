# %% [markdown]
# # visualizing of plots

# %% [markdown]
# To visualize the spread of corner deviations, the DataFrame obtained from the deviation.json file is sorted by the "mean" value (max -> min).

# %%
# %load_ext autoreload

# %%
# %autoreload 1

# %%
# %aimport main
